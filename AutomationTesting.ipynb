# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from webdriver_manager.chrome import ChromeDriverManager
import pyautogui as py
import cv2
import time
options = Options()
options.add_experimental_option("detach", True)

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), 
                          options = options)
driver.get("https://www.stdb.com/")
driver.maximize_window()

time.sleep(0.5)

STDBLogin = driver.find_element("xpath", 
                         "//nav[@class = 'container']//button[@class = 'button-2']") 
time.sleep(0.5)

actions = ActionChains(driver)
actions.move_to_element(STDBLogin).click().perform()

time.sleep(0.5)

CCIMLogin = driver.find_element("xpath", 
                           "//div[@class = 'login-box']//button[@id = 'btn-login-fonteva']") 
time.sleep(0.5)

actions.move_to_element(CCIMLogin).click().perform()

time.sleep(0.5)

username_textbox = driver.find_element("xpath",
                                       "//div[@class = 'pfm-group-listing-content']//div[@id = 'sfdc_username_container']") 
time.sleep(0.5)

actions.move_to_element(username_textbox).click().send_keys("dougc5250@gmail.com").perform()

time.sleep(0.5)

py.hotkey("tab")

time.sleep(0.5)

py.write("HxuXtbrSqvMCn96")

CCIMLogin2 = driver.find_element("xpath", 
                           "//div[@class = 'pfm-group-listing-content']//button[@class='slds-button slds-button--brand loginButton uiButton--none uiButton']") 
time.sleep(0.5)

actions.move_to_element(CCIMLogin2).click().perform()

time.sleep(10)

py.hotkey("ctrl", "t")
py.write('https://stdb.auth0.com/samlp/MDbhKdROoiahAIlOHZLYPP1Fj9lC7yt1?RelayState=https://bao.arcgis.com/esriBAO/index.html?')
time.sleep(5)
py.hotkey("enter")

# BATool = driver.find_element("xpath", 
#                            "//div[@class = 'large-card']")
# time.sleep(0.5)

# actions.move_to_element(BATool).click().perform()


# //*[text()[contains(., 'Business Analyst (Including New STDB Map Site) ')]]
#//a[contains(@href, 'https://stdb.auth0.com/samlp/MDbhKdROoiahAIlOHZLYPP1Fj9lC7yt1?RelayState=https://bao.arcgis.com/esriBAO/index.html?')]

# %%
####testing

# username_textbox = driver.find_element("xpath", 
#                     "//div[contains(@class, 'uiInput uiInputText uiInput--default uiInput--input')][.//input[contains(@placeholder, 'Username')]]")       

# time.sleep(1)

# username_textbox.send_keys("dougc5250@gmail.com")


# print(username_textbox)

# username_textbox = driver.find_element("xpath", 
#                                        "//div[contains(@class, 'ui-widget')][.//input[contains(@class, 'assistiveText')]]")



# for textbox in username_testbox
# print (textbox.get_attribute("innerHTML"))


# [.//input[contains(@placeholder, 'Username')]
# username_textbox.send_keys("dougc5250@gmail.com")

# links = driver.find_elements("xpath", "//a[@href]")
# for link in links:
#   if "CCIM Member LOG IN" in link.get_attribute("innerHTML"):
#       link.click()
#       break
    
# login_links = driver.find_elements("xpath",
#                                    "//li[contains(@class, 'ng-star-inserted')][.//button[text()[contains(., 'LOG IN')]]]")



# for login_links in login_links:
    # print(login_links.get_attribute("href"))

# %%
#locating google chrome opening it and a new tab
# googleChromeLocation = py.locateCenterOnScreen("googleChrome.png", confidence=0.9)
# print(googleChromeLocation)
# py.moveTo(googleChromeLocation)
# py.pause=2.5
# py.click()
# py.pause=2.5
# py.hotkey("ctrl", "t")
# py.pause=5

py.hotkey('win', 'r')
time.sleep(0.5)

py.write('chrome https://www.google.com')
py.press('enter')

time.sleep(1)
py.hotkey("ctrl", "t")
time.sleep(0.5)
py.write("https://www.stdb.com/")
time.sleep(0.5)
py.hotkey("enter")
time.sleep(0.5)


# py.moveTo(1145, 142)
# time.sleep(1)
# py.click()
# time.sleep(1)
# py.moveTo(407, 473)
# time.sleep(1)
# py.click()

stdbLogin = py.locateCenterOnScreen("stdbLogin.png", confidence=0.8)
time.sleep(0.5)
print(stdbLogin)
py.moveTo(stdbLogin)
time.sleep(0.5)
py.click()
time.sleep(0.5)

stdbLogin = py.locateCenterOnScreen("stdbLogin.png", confidence=0.8)
time.sleep(0.5)
print(stdbLogin)
py.moveTo(stdbLogin)
time.sleep(0.5)
py.click()
time.sleep(0.5)



CCIM = py.locateCenterOnScreen("CCIMLogin.png", confidence=0.6)
time.sleep(0.5)
print(CCIM)
py.moveTo(CCIM)
time.sleep(0.5)
py.click()
time.sleep(0.5)

BA = py.locateCenterOnScreen("BusinessAnalyst.png", confidence=0.7)
time.sleep(0.5)
print(BA)
py.moveTo(BA)
time.sleep(0.5)
py.click()
time.sleep(0.5)

BA = py.locateCenterOnScreen("BusinessAnalyst.png", confidence=0.65)
time.sleep(0.5)
print(BA)
py.moveTo(BA)
time.sleep(0.5)
py.click()
time.sleep(1)
# Out:
# None
# None
# None
# None
# None
# None

# %%
#navigating to site to do business and login screen
py.write("https://https://www.stdb.com/")
py.hotkey("enter")
py.pause=2.5
stdbLogin = py.locateCenterOnScreen("stdbLogin.png", confidence=0.3)
py.pause=2.5
print(stdbLogin)
py.moveTo(stdbLogin)
py.pause=2.5
py.click()
py.pause=2.5
# Out:
# None

# %% [markdown]
# #login to CCIM
# CCIM = py.locateCenterOnScreen("CCIMLogin.png", confidence=0.8)
# py.pause=2.5
# print(CCIM)
# py.moveTo(CCIM)
# py.pause=2.5
# py.click()
# py.pause=2.5

# %%
BA = py.locateCenterOnScreen("BusinessAnalyst.png", confidence=0.7)
print(BA)
# Out:
# Point(x=739, y=1405)
